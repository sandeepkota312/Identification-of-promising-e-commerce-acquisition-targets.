# %% [markdown]
# Name: Sandeep Kota
#
# Mail id: sandeepkota312@gmail.com
#
# Phone Number: 6304303577

# %%
import pandas as pd
import pyperclip, re

# %% [markdown]
# Loading data from the sheet attached

# %%
data=pd.read_excel('Sample_Longlist_Data.xlsx')

# %%
data['sellerproductcount'][0]
# Out:
# '1-16 of over 100,000 results'

# %% [markdown]
# seperating results from the seller product count

# %%
def parse_sellerproduct_count(data):
    try:
        sdata = data.split(' ')
        temp = sdata[-2].replace(',','')
        return int(temp)
    except:
        return data

# %%
data["sellerproductcount_cleaned"] = data["sellerproductcount"].apply(parse_sellerproduct_count)

# %%
data.sellerratings.str.split(' ')[0]
# Out:
# ['88%', 'positive', 'in', 'the', 'last', '12', 'months', '(118', 'ratings)']

# %% [markdown]
# separating percentage from the seller ratings

# %%
def parse_sellerratings_percent(data):
    try:
        sdata=data.split(' ')
        temp1=sdata[0].replace('%','')
        return int(temp1)
    except:
        return data

# %%
data["sellerratings_percent_cleaned"] = data["sellerratings"].apply(parse_sellerratings_percent)

# %% [markdown]
# separating total ratings from the seller ratings

# %%
def parse_sellerratings_ratings(data):
    try:
        sdata=data.split(' ')
        temp1=sdata[-2].replace('(','')
        return int(temp1)
    except:
        try:
            sdata=data.split(' ')
            temp1=sdata[-3].replace('(','')
            return int(temp1)
        except:
            return data

# %%
data["sellerratings_ratings_cleaned"] = data["sellerratings"].apply(parse_sellerratings_ratings)

# %% [markdown]
# Extracting postive ratings from percentage and total ratings given by seller ratings

# %%
data["sellerratings_positive_ratings_cleaned"]=data["sellerratings_ratings_cleaned"]*data["sellerratings_percent_cleaned"]//100
data["sellerratings_positive_ratings_cleaned"]
# Out:
# 0       103.0
# 1       509.0
# 2        63.0
# 3         NaN
# 4        42.0
#         ...
# 1834     38.0
# 1835      NaN
# 1836      0.0
# 1837      2.0
# 1838      2.0
# Name: sellerratings_positive_ratings_cleaned, Length: 1839, dtype: float64

# %% [markdown]
# Extracting phone number from seller details

# %%
def parse_sellerdetails_phonenumbers(data):
    try:
        pattern=r'((Telefon|Telefax|Telefax|Fax|\+)+[:. ]?([0-9 -/().]*[0-9]))'
        sdata=data
        temp1=re.findall(pattern, sdata)
        temp1 = [str(a[0]).replace('Telefon:','') for a in temp1]
        return ','.join(temp1)
    except:
        return 'nan'

# %%
data["sellerdetails_phonenumbers_cleaned"] = data["sellerdetails"].apply(parse_sellerdetails_phonenumbers)

# %%
data["sellerdetails_phonenumbers_cleaned"]
# Out:
# 0       +1208-964-6807,+1208-964-6807
# 1
# 2
# 3
# 4
#                     ...
# 1834
# 1835
# 1836
# 1837
# 1838
# Name: sellerdetails_phonenumbers_cleaned, Length: 1839, dtype: object

# %% [markdown]
# Extracting mail id from seller details

# %%
def parse_sellerdetails_mailid(data):
    pattern='([A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\.[A-Z|a-z]{2,})'#'^[a-z 0-9]+[\._]?[a-z 0-9]+[@]\w+[.]\w{2,3}$'
    try:
        sdata=data
        temp1=",".join(re.findall(pattern, sdata)) #.replace('E-Mail:','')  
        return temp1.replace('E-Mail:','')
    except:
        return data

# %%
data["sellerdetails_mailid_cleaned"] = data["sellerdetails"].apply(parse_sellerdetails_mailid)

# %% [markdown]
# Extracting business address from seller details

# %%
def parse_businessaddress(data):
    try:
        sdata=data.replace(' ','')
        temp1=sdata[-2:]
        return temp1
    except:
        return 'nan'

# %%
data["businessaddress_cleaned"] = data["businessaddress"].apply(parse_businessaddress)

# %% [markdown]
# Extracting business name from seller details

# %%
data["seller business name"][1].split(':')[-1]
# Out:
# '1a-Handelsagentur'

# %%
def seller_business_name(data):
    try:
        sdata=data.split(':')
        return sdata[-1]
    except:
        return 'nan'

# %%
data["seller_business_name"] = data["seller business name"].apply(seller_business_name)

# %%
data.head()
# Out:
#   Date Added category sellerlink sellerlink-url     sellerstorefront-url  \
# 0 2020-11-15   Garden   Seller 1  Seller 1-link  Seller 1-storefrontlink
# 1 2020-11-15   Garden   Seller 2  Seller 2-link  Seller 2-storefrontlink
# 2 2020-11-15   Garden   Seller 3  Seller 3-link  Seller 3-storefrontlink
# 3 2020-11-15   Garden   Seller 4  Seller 4-link  Seller 4-storefrontlink
# 4 2020-11-15   Garden   Seller 5  Seller 5-link  Seller 5-storefrontlink
#
#              sellerproductcount  \
# 0  1-16 of over 100,000 results
# 1                           NaN
# 2    1-16 of over 2,000 results
# 3           1-16 of 123 results
# 4    1-16 of over 1,000 results
#
#                                       sellerratings  \
# 0  88% positive in the last 12 months (118 ratings)
# 1  90% positive in the last 12 months (566 ratings)
# 2   85% positive in the last 12 months (75 ratings)
# 3                                               NaN
# 4   81% positive in the last 12 months (52 ratings)
#
#                                        sellerdetails  \
# 0  Lohas Living Inc James Mazzello US 845 3RD Ave...
# 1  Herzlich Willkommen im Amazon Shop von 1a-Hand...
# 2  67878u6i7 is committed to providing each custo...
# 3  7 days home life supermarket is committed to p...
# 4  78 68yui678 is committed to providing each cus...
#
#                                 seller business name  \
# 0                     Business Name:Lohas Living Inc
# 1                    Business Name:1a-Handelsagentur
# 2  Business Name:nantongaohuanfangzhipinyouxiango...
# 3   Business Name:Zhengzhou Yaoqiong Trading Company
# 4  Business Name:shenzhenfeichangshangmeimaoyiyou...
#
#                                      businessaddress  ...  \
# 0  411 THEODORE FREMD AVESTE 206 SOUTHRyeNY10580-...  ...
# 1  1a HandelsagenturLindenallee 2MalchowMecklenbu...  ...
# 2  zhongnanshijicheng27zhuang1410haochongchuanqun...  ...
# 3         河南省中兴南路福禄街自贸试验区郑州片区（郑东）河南商会大厦1901室450000CN  ...
# 4  minzhidadaoshaxialaocun94dongA901longhuaxinqus...  ...
#
#           Sample brand name  \
# 0  Visit the YAMAZAKI Store
# 1      Visit the tesa Store
# 2                    TXYFYP
# 3                   SHIFENG
# 4                   YUOKI99
#
#                                     Sample Brand URL  \
# 0  https://www.amazon.de/-/en/stores/YAMAZAKI/pag...
# 1  https://www.amazon.de/-/en/stores/tesa/page/12...
# 2  https://www.amazon.de/-/en/s/ref=bl_dp_s_web_0...
# 3  https://www.amazon.de/-/en/s/ref=bl_dp_s_web_0...
# 4  https://www.amazon.de/-/en/s/ref=bl_dp_s_web_0...
#
#    sellerproductcount_cleaned  sellerratings_percent_cleaned  \
# 0                    100000.0                           88.0
# 1                         NaN                           90.0
# 2                      2000.0                           85.0
# 3                       123.0                            NaN
# 4                      1000.0                           81.0
#
#    sellerratings_ratings_cleaned  sellerratings_positive_ratings_cleaned  \
# 0                          118.0                                   103.0
# 1                          566.0                                   509.0
# 2                           75.0                                    63.0
# 3                            NaN                                     NaN
# 4                           52.0                                    42.0
#
#   sellerdetails_phonenumbers_cleaned  \
# 0      +1208-964-6807,+1208-964-6807
# 1
# 2
# 3
# 4
#
#                         sellerdetails_mailid_cleaned  businessaddress_cleaned  \
# 0                              jadgemaello@gmail.com                       US
# 1  info@1a-handelsagentur.de,info@1a-handelsagent...                       DE
# 2                                                                          CN
# 3                                                                          CN
# 4                                                                          CN
#
#                          seller_business_name
# 0                            Lohas Living Inc
# 1                           1a-Handelsagentur
# 2        nantongaohuanfangzhipinyouxiangongsi
# 3          Zhengzhou Yaoqiong Trading Company
# 4  shenzhenfeichangshangmeimaoyiyouxiangongsi
#
# [5 rows x 26 columns]

# %%
len(data) # before filtering countries
# Out:
# 1839

# %%
data=data[data["businessaddress_cleaned"]!='CN']
len(data) # after filtering countries
# Out:
# 602

# %% [markdown]
# seperating cleaned data from the main data

# %%
Parsed_data=data[["sellerproductcount_cleaned","sellerratings_positive_ratings_cleaned","Count of seller brands","Max % of negative seller ratings - last 30 days","Max % of negative seller ratings - last 90 days","Max % of negative seller ratings - last 12 months","Hero Product 1 #ratings","Hero Product 2 #ratings","sellerdetails_phonenumbers_cleaned","sellerdetails_mailid_cleaned","businessaddress_cleaned","seller_business_name"]]
Parsed_data
# Out:
#       sellerproductcount_cleaned  sellerratings_positive_ratings_cleaned  \
# 0                       100000.0                                   103.0
# 1                            NaN                                   509.0
# 5                           28.0                                     NaN
# 14                         919.0                                   112.0
# 19                           NaN                                  2827.0
# ...                          ...                                     ...
# 1808                        52.0                                    16.0
# 1813                       177.0                                    10.0
# 1814                      1000.0                                  2798.0
# 1815                      2000.0                                     4.0
# 1828                         NaN                                     NaN
#
#       Count of seller brands  Max % of negative seller ratings - last 30 days  \
# 0                         16                                               17
# 1                          0                                                2
# 5                         13                                                0
# 14                        15                                                0
# 19                         0                                               18
# ...                      ...                                              ...
# 1808                       8                                                0
# 1813                      15                                                0
# 1814                      15                                                6
# 1815                      16                                                0
# 1828                       0                                                0
#
#       Max % of negative seller ratings - last 90 days  \
# 0                                                  11
# 1                                                   2
# 5                                                   0
# 14                                                  0
# 19                                                 20
# ...                                               ...
# 1808                                                0
# 1813                                                0
# 1814                                                8
# 1815                                                0
# 1828                                                0
#
#       Max % of negative seller ratings - last 12 months  \
# 0                                                    12
# 1                                                     9
# 5                                                     0
# 14                                                    3
# 19                                                   20
# ...                                                 ...
# 1808                                                  0
# 1813                                                  0
# 1814                                                  7
# 1815                                                  0
# 1828                                                  0
#
#       Hero Product 1 #ratings  Hero Product 2 #ratings  \
# 0                        5873                     4957
# 1                           0                        0
# 5                        3284                     2944
# 14                       1446                      921
# 19                          0                        0
# ...                       ...                      ...
# 1808                       65                       41
# 1813                       91                       18
# 1814                      636                      466
# 1815                    27269                    11333
# 1828                        0                        0
#
#      sellerdetails_phonenumbers_cleaned  \
# 0         +1208-964-6807,+1208-964-6807
# 1
# 5
# 14                         015140008562
# 19                      Fax: 0570591156
# ...                                 ...
# 1808
# 1813
# 1814                       023626057826
# 1815
# 1828                                nan
#
#                            sellerdetails_mailid_cleaned  \
# 0                                 jadgemaello@gmail.com
# 1     info@1a-handelsagentur.de,info@1a-handelsagent...
# 5
# 14                               webmaster@9pm-store.de
# 19                                     abc-markt@web.de
# ...                                                 ...
# 1808
# 1813              info@zurrosakuh.de,info@zurrosakuh.de
# 1814  r.joormann@googlemail.com,r.joormann@googlemai...
# 1815
# 1828                                                NaN
#
#      businessaddress_cleaned                    seller_business_name
# 0                         US                        Lohas Living Inc
# 1                         DE                       1a-Handelsagentur
# 5                        nan                                     nan
# 14                        DE                            Oliver Mills
# 19                        DE               ABC-Schnäppchenmarkt GmbH
# ...                      ...                                     ...
# 1808                      DE           AD-ACCESS-Zündholz Riesa GmbH
# 1813                     nan                             DE815289413
# 1814                      DE  Reinhard Joormann -FansandTrends- e.K.
# 1815                      NL                             Zwoofer.com
# 1828                     nan                                     nan
#
# [602 rows x 12 columns]

# %% [markdown]
# Normalising values

# %%
def Normalise(s):
    try:
        norm=(s-s.min())/(s.max()-s.min())
        return norm
    except:
        return data

# %%
Normalised_data=pd.DataFrame()
Normalised_data['Normalised_sellerproductcount'] = Normalise(Parsed_data["sellerproductcount_cleaned"])
Normalised_data['Normalised_sellerratings_positive_ratings'] = Normalise(Parsed_data["sellerratings_positive_ratings_cleaned"])
Normalised_data['Normalised_Count_of_seller_brands'] = Normalise(Parsed_data["Count of seller brands"])
Normalised_data['Normalised_negative_seller_ratings_last_12_months'] = Normalise(Parsed_data["Max % of negative seller ratings - last 12 months"])
Normalised_data['Hero_Product_1'] = Normalise(Parsed_data["Hero Product 1 #ratings"])
Normalised_data['Hero_Product_2'] = Normalise(Parsed_data["Hero Product 2 #ratings"])

Normalised_data['phonenumbers'] = Parsed_data['sellerdetails_phonenumbers_cleaned']
Normalised_data['mailid'] = Parsed_data['sellerdetails_mailid_cleaned']
Normalised_data['country'] = Parsed_data['businessaddress_cleaned']
Normalised_data['seller_business_name'] = Parsed_data['seller_business_name']

Normalised_data
# Out:
#       Normalised_sellerproductcount  \
# 0                          0.499992
# 1                               NaN
# 5                          0.000125
# 14                         0.004580
# 19                              NaN
# ...                             ...
# 1808                       0.000245
# 1813                       0.000870
# 1814                       0.004985
# 1815                       0.009985
# 1828                            NaN
#
#       Normalised_sellerratings_positive_ratings  \
# 0                                      0.002921
# 1                                      0.014433
# 5                                           NaN
# 14                                     0.003176
# 19                                     0.080160
# ...                                         ...
# 1808                                   0.000454
# 1813                                   0.000284
# 1814                                   0.079338
# 1815                                   0.000113
# 1828                                        NaN
#
#       Normalised_Count_of_seller_brands  \
# 0                                1.0000
# 1                                0.0000
# 5                                0.8125
# 14                               0.9375
# 19                               0.0000
# ...                                 ...
# 1808                             0.5000
# 1813                             0.9375
# 1814                             0.9375
# 1815                             1.0000
# 1828                             0.0000
#
#       Normalised_negative_seller_ratings_last_12_months  Hero_Product_1  \
# 0                                                  0.12        0.067618
# 1                                                  0.09        0.000000
# 5                                                  0.00        0.037810
# 14                                                 0.03        0.016648
# 19                                                 0.20        0.000000
# ...                                                 ...             ...
# 1808                                               0.00        0.000748
# 1813                                               0.00        0.001048
# 1814                                               0.07        0.007322
# 1815                                               0.00        0.313956
# 1828                                               0.00        0.000000
#
#       Hero_Product_2                   phonenumbers  \
# 0           0.070081  +1208-964-6807,+1208-964-6807
# 1           0.000000
# 5           0.041622
# 14          0.013021                   015140008562
# 19          0.000000                Fax: 0570591156
# ...              ...                            ...
# 1808        0.000580
# 1813        0.000254
# 1814        0.006588                   023626057826
# 1815        0.160225
# 1828        0.000000                            nan
#
#                                                  mailid country  \
# 0                                 jadgemaello@gmail.com      US
# 1     info@1a-handelsagentur.de,info@1a-handelsagent...      DE
# 5                                                           nan
# 14                               webmaster@9pm-store.de      DE
# 19                                     abc-markt@web.de      DE
# ...                                                 ...     ...
# 1808                                                         DE
# 1813              info@zurrosakuh.de,info@zurrosakuh.de     nan
# 1814  r.joormann@googlemail.com,r.joormann@googlemai...      DE
# 1815                                                         NL
# 1828                                                NaN     nan
#
#                         seller_business_name
# 0                           Lohas Living Inc
# 1                          1a-Handelsagentur
# 5                                        nan
# 14                              Oliver Mills
# 19                 ABC-Schnäppchenmarkt GmbH
# ...                                      ...
# 1808           AD-ACCESS-Zündholz Riesa GmbH
# 1813                             DE815289413
# 1814  Reinhard Joormann -FansandTrends- e.K.
# 1815                             Zwoofer.com
# 1828                                     nan
#
# [602 rows x 10 columns]

# %% [markdown]
# Averaging both Hero product 1 and Hero product 2

# %%
Normalised_data['Hero_Product']=(Normalised_data['Hero_Product_1'] + Normalised_data['Hero_Product_2'])/2
Normalised_data
# Out:
#       Normalised_sellerproductcount  \
# 0                          0.499992
# 1                               NaN
# 5                          0.000125
# 14                         0.004580
# 19                              NaN
# ...                             ...
# 1808                       0.000245
# 1813                       0.000870
# 1814                       0.004985
# 1815                       0.009985
# 1828                            NaN
#
#       Normalised_sellerratings_positive_ratings  \
# 0                                      0.002921
# 1                                      0.014433
# 5                                           NaN
# 14                                     0.003176
# 19                                     0.080160
# ...                                         ...
# 1808                                   0.000454
# 1813                                   0.000284
# 1814                                   0.079338
# 1815                                   0.000113
# 1828                                        NaN
#
#       Normalised_Count_of_seller_brands  \
# 0                                1.0000
# 1                                0.0000
# 5                                0.8125
# 14                               0.9375
# 19                               0.0000
# ...                                 ...
# 1808                             0.5000
# 1813                             0.9375
# 1814                             0.9375
# 1815                             1.0000
# 1828                             0.0000
#
#       Normalised_negative_seller_ratings_last_12_months  Hero_Product_1  \
# 0                                                  0.12        0.067618
# 1                                                  0.09        0.000000
# 5                                                  0.00        0.037810
# 14                                                 0.03        0.016648
# 19                                                 0.20        0.000000
# ...                                                 ...             ...
# 1808                                               0.00        0.000748
# 1813                                               0.00        0.001048
# 1814                                               0.07        0.007322
# 1815                                               0.00        0.313956
# 1828                                               0.00        0.000000
#
#       Hero_Product_2                   phonenumbers  \
# 0           0.070081  +1208-964-6807,+1208-964-6807
# 1           0.000000
# 5           0.041622
# 14          0.013021                   015140008562
# 19          0.000000                Fax: 0570591156
# ...              ...                            ...
# 1808        0.000580
# 1813        0.000254
# 1814        0.006588                   023626057826
# 1815        0.160225
# 1828        0.000000                            nan
#
#                                                  mailid country  \
# 0                                 jadgemaello@gmail.com      US
# 1     info@1a-handelsagentur.de,info@1a-handelsagent...      DE
# 5                                                           nan
# 14                               webmaster@9pm-store.de      DE
# 19                                     abc-markt@web.de      DE
# ...                                                 ...     ...
# 1808                                                         DE
# 1813              info@zurrosakuh.de,info@zurrosakuh.de     nan
# 1814  r.joormann@googlemail.com,r.joormann@googlemai...      DE
# 1815                                                         NL
# 1828                                                NaN     nan
#
#                         seller_business_name  Hero_Product
# 0                           Lohas Living Inc      0.068850
# 1                          1a-Handelsagentur      0.000000
# 5                                        nan      0.039716
# 14                              Oliver Mills      0.014835
# 19                 ABC-Schnäppchenmarkt GmbH      0.000000
# ...                                      ...           ...
# 1808           AD-ACCESS-Zündholz Riesa GmbH      0.000664
# 1813                             DE815289413      0.000651
# 1814  Reinhard Joormann -FansandTrends- e.K.      0.006955
# 1815                             Zwoofer.com      0.237090
# 1828                                     nan      0.000000
#
# [602 rows x 11 columns]

# %% [markdown]
# Priority order for decision Making:
# 1. Hero_Product - avg of Product 1 and 2(decending) - 5 weight
# 2. Seller positive ratings(decending) - 4 weight
# 3. Max % of negative seller ratings - last 12 months (ascending) - 3 weight
# 4. sellerproductcount(decending) - 2 weight
# 5. Count of seller brands (decending) - 2 weight
#
# Total weight=16

# %%
def score(data):
    p1=data["Hero_Product"]
    p2=data['Normalised_sellerratings_positive_ratings']
    p3=data['Normalised_negative_seller_ratings_last_12_months']
    p4=data['Normalised_sellerproductcount']
    p5=data['Normalised_Count_of_seller_brands']
    return (5/16)*p1+ (1/4)*p2+(3/16)*(1-p3)+(1/8)*p4+(1/8)*p5

Normalised_data['score']=Normalised_data.apply(score, axis=1)
Normalised_data
# Out:
#       Normalised_sellerproductcount  \
# 0                          0.499992
# 1                               NaN
# 5                          0.000125
# 14                         0.004580
# 19                              NaN
# ...                             ...
# 1808                       0.000245
# 1813                       0.000870
# 1814                       0.004985
# 1815                       0.009985
# 1828                            NaN
#
#       Normalised_sellerratings_positive_ratings  \
# 0                                      0.002921
# 1                                      0.014433
# 5                                           NaN
# 14                                     0.003176
# 19                                     0.080160
# ...                                         ...
# 1808                                   0.000454
# 1813                                   0.000284
# 1814                                   0.079338
# 1815                                   0.000113
# 1828                                        NaN
#
#       Normalised_Count_of_seller_brands  \
# 0                                1.0000
# 1                                0.0000
# 5                                0.8125
# 14                               0.9375
# 19                               0.0000
# ...                                 ...
# 1808                             0.5000
# 1813                             0.9375
# 1814                             0.9375
# 1815                             1.0000
# 1828                             0.0000
#
#       Normalised_negative_seller_ratings_last_12_months  Hero_Product_1  \
# 0                                                  0.12        0.067618
# 1                                                  0.09        0.000000
# 5                                                  0.00        0.037810
# 14                                                 0.03        0.016648
# 19                                                 0.20        0.000000
# ...                                                 ...             ...
# 1808                                               0.00        0.000748
# 1813                                               0.00        0.001048
# 1814                                               0.07        0.007322
# 1815                                               0.00        0.313956
# 1828                                               0.00        0.000000
#
#       Hero_Product_2                   phonenumbers  \
# 0           0.070081  +1208-964-6807,+1208-964-6807
# 1           0.000000
# 5           0.041622
# 14          0.013021                   015140008562
# 19          0.000000                Fax: 0570591156
# ...              ...                            ...
# 1808        0.000580
# 1813        0.000254
# 1814        0.006588                   023626057826
# 1815        0.160225
# 1828        0.000000                            nan
#
#                                                  mailid country  \
# 0                                 jadgemaello@gmail.com      US
# 1     info@1a-handelsagentur.de,info@1a-handelsagent...      DE
# 5                                                           nan
# 14                               webmaster@9pm-store.de      DE
# 19                                     abc-markt@web.de      DE
# ...                                                 ...     ...
# 1808                                                         DE
# 1813              info@zurrosakuh.de,info@zurrosakuh.de     nan
# 1814  r.joormann@googlemail.com,r.joormann@googlemai...      DE
# 1815                                                         NL
# 1828                                                NaN     nan
#
#                         seller_business_name  Hero_Product     score
# 0                           Lohas Living Inc      0.068850  0.374745
# 1                          1a-Handelsagentur      0.000000       NaN
# 5                                        nan      0.039716       NaN
# 14                              Oliver Mills      0.014835  0.305065
# 19                 ABC-Schnäppchenmarkt GmbH      0.000000       NaN
# ...                                      ...           ...       ...
# 1808           AD-ACCESS-Zündholz Riesa GmbH      0.000664  0.250352
# 1813                             DE815289413      0.000651  0.305071
# 1814  Reinhard Joormann -FansandTrends- e.K.      0.006955  0.314194
# 1815                             Zwoofer.com      0.237090  0.387867
# 1828                                     nan      0.000000       NaN
#
# [602 rows x 12 columns]

# %%
Normalised_data=Normalised_data.sort_values(by=['score'], ascending=False)
Normalised_data=Normalised_data[Normalised_data["score"] >= Normalised_data["score"].describe()["25%"]] #percentile
Normalised_data
# Out:
#       Normalised_sellerproductcount  \
# 495                        0.499992
# 322                        0.149987
# 947                        0.049986
# 842                        0.039986
# 321                        0.034986
# ...                             ...
# 601                        0.004985
# 1808                       0.000245
# 158                        0.019985
# 1499                       0.002860
# 973                        0.039986
#
#       Normalised_sellerratings_positive_ratings  \
# 495                                    0.007429
# 322                                    0.018232
# 947                                    0.004140
# 842                                    0.001021
# 321                                    0.005217
# ...                                         ...
# 601                                    0.000255
# 1808                                   0.000454
# 158                                    0.001758
# 1499                                   0.000510
# 973                                    0.002212
#
#       Normalised_Count_of_seller_brands  \
# 495                              0.8750
# 322                              1.0000
# 947                              1.0000
# 842                              0.9375
# 321                              1.0000
# ...                                 ...
# 601                              0.9375
# 1808                             0.5000
# 158                              0.5625
# 1499                             0.8750
# 973                              0.5000
#
#       Normalised_negative_seller_ratings_last_12_months  Hero_Product_1  \
# 495                                                0.07        0.894745
# 322                                                0.06        0.825193
# 947                                                0.06        1.000000
# 842                                                0.03        0.825159
# 321                                                0.06        0.695220
# ...                                                 ...             ...
# 601                                                0.33        0.031190
# 1808                                               0.00        0.000748
# 158                                                0.06        0.001739
# 1499                                               0.26        0.001554
# 973                                                0.04        0.000115
#
#       Hero_Product_2                                      phonenumbers  \
# 495         1.000000
# 322         0.824690  +49 59 71/ 8 00 38 03,Fax: +49 59 71/ 8 00 38 06
# 947         0.533224
# 842         0.731706
# 321         0.816731              0371 400 7682,Telefax: 0371 400 7685
# ...              ...                                               ...
# 601         0.024840
# 1808        0.000580
# 158         0.002135                 02454 - 9028162,Fax:02454-9028163
# 1499        0.001089
# 973         0.000127
#
#                       mailid country           seller_business_name  \
# 495                               US           C. Y. MARKETING INC.
# 322          info@limuno.com      DE              Milovan Stojkovic
# 947                               JP            VIP Plaza Japan Inc
# 842                               IT               Vertecchi S.r.l.
# 321     shop@varia-store.com      DE              VARIA System GmbH
# ...                      ...     ...                            ...
# 601                               ES  Juan Rafael Martinez Espinosa
# 1808                              DE  AD-ACCESS-Zündholz Riesa GmbH
# 158   info@sl-handelsgmbh.de      DE                SL-Handels GmbH
# 1499                              GB                   HR ARRON LTD
# 973                               GB          printedguitarpicksltd
#
#       Hero_Product     score
# 495       0.947373  0.644160
# 322       0.824942  0.582351
# 947       0.766612  0.548099
# 842       0.778432  0.547576
# 321       0.755975  0.543170
# ...            ...       ...
# 601       0.028015  0.252254
# 1808      0.000664  0.250352
# 158       0.001937  0.250105
# 1499      0.001321  0.249023
# 973       0.000121  0.248089
#
# [352 rows x 12 columns]

# %% [markdown]
# Seperating Ranked data from the results

# %%
Ranked_data=Normalised_data[['seller_business_name','phonenumbers','mailid','score','country']]
Ranked_data
# Out:
#                seller_business_name  \
# 495            C. Y. MARKETING INC.
# 322               Milovan Stojkovic
# 947             VIP Plaza Japan Inc
# 842                Vertecchi S.r.l.
# 321               VARIA System GmbH
# ...                             ...
# 601   Juan Rafael Martinez Espinosa
# 1808  AD-ACCESS-Zündholz Riesa GmbH
# 158                 SL-Handels GmbH
# 1499                   HR ARRON LTD
# 973           printedguitarpicksltd
#
#                                           phonenumbers  \
# 495
# 322   +49 59 71/ 8 00 38 03,Fax: +49 59 71/ 8 00 38 06
# 947
# 842
# 321               0371 400 7682,Telefax: 0371 400 7685
# ...                                                ...
# 601
# 1808
# 158                  02454 - 9028162,Fax:02454-9028163
# 1499
# 973
#
#                       mailid     score country
# 495                           0.644160      US
# 322          info@limuno.com  0.582351      DE
# 947                           0.548099      JP
# 842                           0.547576      IT
# 321     shop@varia-store.com  0.543170      DE
# ...                      ...       ...     ...
# 601                           0.252254      ES
# 1808                          0.250352      DE
# 158   info@sl-handelsgmbh.de  0.250105      DE
# 1499                          0.249023      GB
# 973                           0.248089      GB
#
# [352 rows x 5 columns]
